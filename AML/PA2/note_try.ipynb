# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(".\mushroom_data.csv")

# %%
df.columns = ["dropable", "cap-shape", "cap-surface", "cap-color", "bruises", "odor", "gill-attachment",
                  "gill-spacing", "gill-size", "gill-color", "stalk-shape", "stalk-root", "stalk-surface-above-ring",
                  "stalk-surface-below-ring", "stalk-color-above-ring", "stalk-color-below-ring", "veil-type",
                  "veil-color", "ring-number", "ring-type", "spore-print-color", "population", "habitat"]

# %%
df = df.drop('dropable', 1)

# %%
label = df['bruises']

# %%
df.drop('bruises', axis=1, inplace=True)

# %%
df.insert(0, 'bruises', label)

# %%
df.head()
# Out:
#   bruises cap-shape cap-surface cap-color odor gill-attachment gill-spacing  \
# 0       t         x           s         y    a               f            c
# 1       t         b           s         w    l               f            c
# 2       t         x           y         w    p               f            c
# 3       f         x           s         g    n               f            w
# 4       t         x           y         y    a               f            c
#
#   gill-size gill-color stalk-shape   ...   stalk-surface-below-ring  \
# 0         b          k           e   ...                          s
# 1         b          n           e   ...                          s
# 2         n          n           e   ...                          s
# 3         b          k           t   ...                          s
# 4         b          n           e   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
datas = np.array(df)

# %%
datas
# Out:
# array([['t', 'x', 's', ..., 'n', 'n', 'g'],
#        ['t', 'b', 's', ..., 'n', 'n', 'm'],
#        ['t', 'x', 'y', ..., 'k', 's', 'u'],
#        ...,
#        ['f', 'f', 's', ..., 'b', 'c', 'l'],
#        ['f', 'k', 'y', ..., 'w', 'v', 'l'],
#        ['f', 'x', 's', ..., 'o', 'c', 'l']], dtype=object)

# %%
val = df.bruises.unique()

# %%
val
# Out:
# array(['t', 'f'], dtype=object)

# %%
skeleton = []
for col in df.columns:
    skeleton.append(df[col].unique())

# %%
skeleton
# Out:
# [array(['t', 'f'], dtype=object),
#  array(['x', 'b', 's', 'f', 'k', 'c'], dtype=object),
#  array(['s', 'y', 'f', 'g'], dtype=object),
#  array(['y', 'w', 'g', 'n', 'e', 'p', 'b', 'u', 'c', 'r'], dtype=object),
#  array(['a', 'l', 'p', 'n', 'f', 'c', 'y', 's', 'm'], dtype=object),
#  array(['f', 'a'], dtype=object),
#  array(['c', 'w'], dtype=object),
#  array(['b', 'n'], dtype=object),
#  array(['k', 'n', 'g', 'p', 'w', 'h', 'u', 'e', 'b', 'r', 'y', 'o'], dtype=object),
#  array(['e', 't'], dtype=object),
#  array(['c', 'e', 'b', 'r', '?'], dtype=object),
#  array(['s', 'f', 'k', 'y'], dtype=object),
#  array(['s', 'f', 'y', 'k'], dtype=object),
#  array(['w', 'g', 'p', 'n', 'b', 'e', 'o', 'c', 'y'], dtype=object),
#  array(['w', 'p', 'g', 'b', 'n', 'e', 'y', 'o', 'c'], dtype=object),
#  array(['p'], dtype=object),
#  array(['w', 'n', 'o', 'y'], dtype=object),
#  array(['o', 't', 'n'], dtype=object),
#  array(['p', 'e', 'l', 'f', 'n'], dtype=object),
# ...

# %%
col = df.columns[0]

# %%
col
# Out:
# 'bruises'

# %%
from collections import Counter

# %%
def get_values(df, attrib):
    count = Counter()
    for v in df[attrib]:
        count[v] += 1
    return count

# %%
count = get_values(df, col)
count
# Out:
# Counter({'d': 3148,
#          'g': 2148,
#          'l': 832,
#          'm': 292,
#          'p': 1144,
#          'u': 367,
#          'w': 192})

# %%
def get_data_skeleton(df):
    dataskeleton = {}
    i = 0
    for col in df.columns:
        dataskeleton[i] = get_values(df, col)
        i += 1
    return dataskeleton

# %%
dataskeleton = get_data_skeleton(df)

# %%
dataskeleton
# Out:
# {0: Counter({'f': 4748, 't': 3375}),
#  1: Counter({'b': 452, 'c': 4, 'f': 3152, 'k': 828, 's': 32, 'x': 3655}),
#  2: Counter({'f': 2320, 'g': 4, 's': 2555, 'y': 3244}),
#  3: Counter({'b': 168,
#           'c': 44,
#           'e': 1500,
#           'g': 1840,
#           'n': 2283,
#           'p': 144,
#           'r': 16,
#           'u': 16,
#           'w': 1040,
#           'y': 1072}),
#  4: Counter({'a': 400,
#           'c': 192,
#           'f': 2160,
#           'l': 400,
#           'm': 36,
#           'n': 3528,
#           'p': 255,
#           's': 576,
#           'y': 576}),
#  5: Counter({'a': 210, 'f': 7913}),
#  6: Counter({'c': 6811, 'w': 1312}),
#  7: Counter({'b': 5612, 'n': 2511}),
#  8: Counter({'b': 1728,
#           'e': 96,
#           'g': 752,
#           'h': 732,
#           'k': 407,
#           'n': 1048,
#           'o': 64,
#           'p': 1492,
#           'r': 24,
#           'u': 492,
#           'w': 1202,
#           'y': 86}),
# ...

# %%
df1 = pd.read_csv("agaricuslepiotatrain1.csv")

# %%
df1.head()
# Out:
#    cap-shape-bell  cap-shape-conical  cap-shape-convex  cap-shape-flat  \
# 0               0                  0                 1               0
# 1               0                  0                 1               0
# 2               1                  0                 0               0
# 3               0                  0                 1               0
# 4               0                  0                 1               0
#
#    cap-shape-knobbed  cap-shape-sunken  cap-surface-fibrous  \
# 0                  0                 0                    0
# 1                  0                 0                    0
# 2                  0                 0                    0
# 3                  0                 0                    0
# 4                  0                 0                    0
#
#    cap-surface-grooves  cap-surface-scaly  cap-surface-smooth    ...      \
# 0                    0                  0                   1    ...
# ...

# %%
df1.columns
# Out:
# Index(['cap-shape-bell', 'cap-shape-conical', 'cap-shape-convex',
#        'cap-shape-flat', 'cap-shape-knobbed', 'cap-shape-sunken',
#        'cap-surface-fibrous', 'cap-surface-grooves', 'cap-surface-scaly',
#        'cap-surface-smooth',
#        ...
#        'population-several', 'population-solitary', 'habitat-grasses',
#        'habitat-leaves', 'habitat-meadows', 'habitat-paths', 'habitat-urban',
#        'habitat-waste', 'habitat-woods', 'poisonous'],
#       dtype='object', length=127)

# %%
df1.drop(df1['poisonous'])
# Out:
#       cap-shape-bell  cap-shape-conical  cap-shape-convex  cap-shape-flat  \
# 2                  1                  0                 0               0
# 3                  0                  0                 1               0
# 4                  0                  0                 1               0
# 5                  0                  0                 1               0
# 6                  1                  0                 0               0
# 7                  1                  0                 0               0
# 8                  0                  0                 1               0
# 9                  1                  0                 0               0
# 10                 0                  0                 1               0
# 11                 0                  0                 1               0
# 12                 1                  0                 0               0
# 13                 0                  0                 1               0
# ...
